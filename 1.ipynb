# %%
def caudal_vogel(caudal_maximo, presion_yacimiento,presion_fondo):
    caudal = caudal_maximo*( 1 - 0.2*(presion_fondo/ presion_yacimiento) - 0.8*((presion_fondo/ presion_yacimiento)**2))
    return round(caudal,2)

# %%
caudal_vogel(1200, 3000,1500)
# Out:
# 840.0

# %%
caudal_vogel(1200, 3000, [3000, 2500, 2000, 1500, 500, 0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 caudal_vogel(1200, 3000, [3000, 2500, 2000, 1500, 500, 0])
#
# Cell In[12], line 2, in caudal_vogel(caudal_maximo, presion_yacimiento, presion_fondo)
#       1 def caudal_vogel(caudal_maximo, presion_yacimiento,presion_fondo):
# ----> 2     caudal = caudal_maximo*( 1 - 0.2*(presion_fondo/ presion_yacimiento) - 0.8*((presion_fondo/ presion_yacimiento)**2))
#       3     return round(caudal,2)
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'
